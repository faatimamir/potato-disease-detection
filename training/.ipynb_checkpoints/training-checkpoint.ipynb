# %%
import tensorflow as tf
from tensorflow.keras import models, layers


from IPython.display import HTML

# %%
# !pip install --upgrade matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\faati\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS=3
EPOCHS=50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)
# Out:
# 68

# %%
for image_batch,label_batch in dataset.take(1):
    plt.title(class_names[label_batch[0]])
    plt.imshow(image_batch[0].numpy().astype("uint8"))
    print(image_batch[0].shape)
# Out:
# (256, 256, 3)

# %%
for image_batch,label_batch in dataset.take(1):
    plt.imshow(image_batch[0].numpy().astype("uint8"))
    plt.axis("off")
    print(image_batch[0].shape)
# Out:
# (256, 256, 3)
